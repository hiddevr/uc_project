# %%
import pandas as pd

df = pd.read_csv('escooter_data.csv')
df = df.dropna(subset=['Start Centroid Longitude', 'End Centroid Longitude'])
df.head()
# Out:
#                                     Trip ID              Start Time  \
# 10291  0dd95046-1bc8-4464-ba39-7f9e92c668b3  08/06/2019 06:00:00 PM
# 10293  6819df6a-9623-4ae0-b1d3-ec617197d229  07/08/2019 04:00:00 PM
# 10342  aa71bb53-3e7f-4964-b6e6-030800419346  08/10/2019 09:00:00 PM
# 10367  5d256770-1a8a-5e20-8f78-316d1819f46b  06/25/2019 07:00:00 PM
# 10369  dffe5324-5f6f-48e7-9edf-d51876ba7d2f  09/19/2019 08:00:00 AM
#
#                      End Time  Trip Distance  Trip Duration  Accuracy  \
# 10291  08/06/2019 06:00:00 PM           1004            236       152
# 10293  07/08/2019 05:00:00 PM           9124           3182        10
# 10342  08/10/2019 09:00:00 PM            502             97       152
# 10367  06/25/2019 08:00:00 PM           5053           2167         0
# 10369  09/19/2019 08:00:00 AM            790            111       152
#
#        Start Census Tract  End Census Tract  Start Community Area Number  \
# 10291        1.703120e+10      1.703120e+10                         20.0
# 10293        1.703115e+10      1.703119e+10                         15.0
# 10342        1.703184e+10      1.703184e+10                         27.0
# 10367        1.703122e+10      1.703119e+10                         22.0
# 10369        1.703119e+10      1.703120e+10                         19.0
#
#        End Community Area Number Start Community Area Name  \
# 10291                       20.0                   HERMOSA
# 10293                       19.0              PORTAGE PARK
# 10342                       27.0        EAST GARFIELD PARK
# 10367                       19.0              LOGAN SQUARE
# 10369                       20.0            BELMONT CRAGIN
#
#       End Community Area Name  Start Centroid Latitude  \
# 10291                 HERMOSA                41.935048
# 10293          BELMONT CRAGIN                41.949592
# 10342      EAST GARFIELD PARK                41.885045
# 10367          BELMONT CRAGIN                41.921126
# 10369                 HERMOSA                41.935218
#
#        Start Centroid Longitude                      Start Centroid Location  \
# 10291                -87.737604   POINT (-87.7376041954734 41.9350481285613)
# 10293                -87.761958   POINT (-87.7619580301513 41.9495915671753)
# 10342                -87.713862  POINT (-87.71386248059811 41.8850448415253)
# 10367                -87.699754   POINT (-87.6997540616386 41.9211256768265)
# 10369                -87.744389   POINT (-87.7443888733072 41.9352176386575)
#
#        End Centroid Latitude  End Centroid Longitude  \
# 10291              41.935048              -87.737604
# 10293              41.920143              -87.760827
# 10342              41.885045              -87.713862
# 10367              41.927819              -87.751362
# 10369              41.927852              -87.735628
#
#                              End Centroid Location
# 10291   POINT (-87.7376041954734 41.9350481285613)
# 10293    POINT (-87.7608269556143 41.920143229102)
# 10342  POINT (-87.71386248059811 41.8850448415253)
# 10367   POINT (-87.7513623675995 41.9278186319205)
# 10369   POINT (-87.7356282729632 41.9278522690551)

# %%
from tqdm.notebook import tqdm

df['Start Time'] = pd.to_datetime(df['Start Time'], format='%m/%d/%Y %I:%M:%S %p')
df['End Time'] = pd.to_datetime(df['End Time'], format='%m/%d/%Y %I:%M:%S %p')
df.sort_values(by='Start Time', inplace=True)

# Dictionary to map end locations of previous trips to e-scooter IDs
end_location_to_escooter_id = {}

# Dictionary to store cumulative distance for each e-scooter ID and date
cumulative_distance = {}

# Process each day separately
for date, group in tqdm(df.groupby(df['Start Time'].dt.date), desc="Processing Days"):
    e_id = 1  # Reset e-scooter ID for each day
    end_location_to_escooter_id.clear()

    for index, row in group.iterrows():
        start_location = row['Start Centroid Location']
        end_location = row['End Centroid Location']
        trip_distance = row['Trip Duration']

        # Check if the trip starts where a previous trip ended
        if start_location in end_location_to_escooter_id:
            scooter_id = end_location_to_escooter_id[start_location]
        else:
            scooter_id = e_id
            cumulative_distance[(scooter_id, date)] = 0  # Initialize cumulative distance for new e-scooter
            e_id += 1

        # Add the current cumulative distance to the dataframe
        df.loc[index, 'Cumulative Distance at Start'] = cumulative_distance[(scooter_id, date)]

        # Update the cumulative distance and end location for this e-scooter
        cumulative_distance[(scooter_id, date)] += trip_distance
        end_location_to_escooter_id[end_location] = scooter_id
        
df
# Out:
# Processing Days:   0%|          | 0/111 [00:00<?, ?it/s]
#                                      Trip ID          Start Time  \
# 148345  0b6cc3f2-0a61-43a5-928f-0de692aa8a2b 2019-06-15 04:00:00
# 241809  4793f3c4-77ed-416b-b72a-2e9bfbcd311c 2019-06-15 06:00:00
# 223923  297b2b72-f371-45b1-8ac0-821a9b0d6ad3 2019-06-15 06:00:00
# 126554  e081485f-81c2-5780-beda-cc05217dcd2c 2019-06-15 06:00:00
# 324537  d5ec7eaf-4b5b-467c-bfc1-b6b918eef1a0 2019-06-15 06:00:00
# ...                                      ...                 ...
# 301191  977edd2a-a5e3-52da-640a-15f05c2d382f 2019-10-16 00:00:00
# 305215  b65717f2-4c66-e992-ebf2-66e6de0c4144 2019-10-16 00:00:00
# 290196  b8592dce-7847-1709-734f-a7cf93d5633f 2019-10-16 00:00:00
# 404153  08cc0735-2a60-1e07-256c-1b80c84b481a 2019-10-16 00:00:00
# 547284  86bc8fd6-2d48-137b-948d-34e89cae4a99 2019-10-16 00:00:00
#
#                   End Time  Trip Distance  Trip Duration  Accuracy  \
# 148345 2019-06-15 05:00:00            688           3921       152
# 241809 2019-06-15 06:00:00              0              5        10
# 223923 2019-06-15 06:00:00           2078            383       152
# 126554 2019-06-15 06:00:00           4473           1831         0
# 324537 2019-06-15 06:00:00           1073            299       152
# ...                    ...            ...            ...       ...
# 301191 2019-10-16 00:00:00           3846            694        10
# 305215 2019-10-16 00:00:00           1874            372        10
# 290196 2019-10-16 00:00:00            363             86        10
# 404153 2019-10-16 00:00:00           1144            392        10
# 547284 2019-10-16 03:00:00           8587          10838        10
#
#         Start Census Tract  End Census Tract  Start Community Area Number  \
# 148345                 NaN               NaN                         31.0
# 241809                 NaN               NaN                         28.0
# 223923        1.703183e+10      1.703183e+10                         28.0
# 126554                 NaN               NaN                         22.0
# 324537        1.703183e+10      1.703183e+10                         28.0
# ...                    ...               ...                          ...
# 301191                 NaN               NaN                         28.0
# 305215                 NaN               NaN                         28.0
# 290196                 NaN               NaN                         28.0
# 404153                 NaN               NaN                         28.0
# 547284                 NaN               NaN                         24.0
#
#         End Community Area Number Start Community Area Name  \
# 148345                       31.0           LOWER WEST SIDE
# 241809                       28.0            NEAR WEST SIDE
# 223923                       28.0            NEAR WEST SIDE
# 126554                       22.0              LOGAN SQUARE
# 324537                       28.0            NEAR WEST SIDE
# ...                           ...                       ...
# 301191                       28.0            NEAR WEST SIDE
# 305215                       28.0            NEAR WEST SIDE
# 290196                       28.0            NEAR WEST SIDE
# 404153                       24.0            NEAR WEST SIDE
# 547284                       24.0                 WEST TOWN
#
#        End Community Area Name  Start Centroid Latitude  \
# 148345         LOWER WEST SIDE                41.850266
# 241809          NEAR WEST SIDE                41.874005
# 223923          NEAR WEST SIDE                41.879077
# 126554            LOGAN SQUARE                41.922760
# 324537          NEAR WEST SIDE                41.879077
# ...                        ...                      ...
# 301191          NEAR WEST SIDE                41.874005
# 305215          NEAR WEST SIDE                41.874005
# 290196          NEAR WEST SIDE                41.874005
# 404153               WEST TOWN                41.874005
# 547284               WEST TOWN                41.901207
#
#         Start Centroid Longitude                     Start Centroid Location  \
# 148345                -87.667568  POINT (-87.6675682255936 41.8502661710639)
# 241809                -87.663518  POINT (-87.6635178867003 41.8740053848845)
# 223923                -87.657045    POINT (-87.65704538762 41.8790767308624)
# 126554                -87.699156  POINT (-87.6991559457654 41.9227598585219)
# 324537                -87.657045    POINT (-87.65704538762 41.8790767308624)
# ...                          ...                                         ...
# 301191                -87.663518  POINT (-87.6635178867003 41.8740053848845)
# 305215                -87.663518  POINT (-87.6635178867003 41.8740053848845)
# 290196                -87.663518  POINT (-87.6635178867003 41.8740053848845)
# 404153                -87.663518  POINT (-87.6635178867003 41.8740053848845)
# 547284                -87.676357  POINT (-87.6763571260391 41.9012067343156)
#
#         End Centroid Latitude  End Centroid Longitude  \
# 148345              41.850266              -87.667568
# 241809              41.874005              -87.663518
# 223923              41.879077              -87.657045
# 126554              41.922760              -87.699156
# 324537              41.879077              -87.657045
# ...                       ...                     ...
# 301191              41.874005              -87.663518
# 305215              41.874005              -87.663518
# 290196              41.874005              -87.663518
# 404153              41.901207              -87.676357
# 547284              41.901207              -87.676357
#
#                              End Centroid Location  \
# 148345  POINT (-87.6675682255936 41.8502661710639)
# 241809  POINT (-87.6635178867003 41.8740053848845)
# 223923    POINT (-87.65704538762 41.8790767308624)
# 126554  POINT (-87.6991559457654 41.9227598585219)
# 324537    POINT (-87.65704538762 41.8790767308624)
# ...                                            ...
# 301191  POINT (-87.6635178867003 41.8740053848845)
# 305215  POINT (-87.6635178867003 41.8740053848845)
# 290196  POINT (-87.6635178867003 41.8740053848845)
# 404153  POINT (-87.6763571260391 41.9012067343156)
# 547284  POINT (-87.6763571260391 41.9012067343156)
#
#         Cumulative Distance at Start
# 148345                           0.0
# 241809                           0.0
# 223923                           0.0
# 126554                           0.0
# 324537                         383.0
# ...                              ...
# 301191                         373.0
# 305215                        1067.0
# 290196                        1439.0
# 404153                        1525.0
# 547284                        1917.0
#
# [612570 rows x 19 columns]

# %%
top_10_percent_start = df['Cumulative Distance at Start'].quantile(0.9)
top_10_percent_start
# Out:
# 1090013.4

# %%
import matplotlib.pyplot as plt

Q1 = df['Trip Duration'].quantile(0.25)
Q3 = df['Trip Duration'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

filtered_distances = df['Trip Duration'][(df['Trip Duration'] >= lower_bound) & (df['Trip Duration'] <= upper_bound)]

plt.figure(figsize=(10, 6))
plt.hist(filtered_distances, bins='auto', color='skyblue', alpha=0.7)
plt.title('Histogram of Total Distance Travelled by E-Scooters (Without Outliers)')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.grid(True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import gaussian_kde

bw_values = [0.1, 0.15, 0.2, 0.25]
for bw in bw_values:
    kde = gaussian_kde(filtered_distances, bw_method=bw)
    dist_space = np.linspace(min(filtered_distances), max(filtered_distances), 100)
    plt.plot(dist_space, kde(dist_space), label=f'KDE with bw={bw}')

plt.hist(filtered_distances, bins=50, density=True, alpha=0.5, label='Histogram')
plt.title('Kernel Density Estimation with Different Bandwidths')
plt.xlabel('Distance')
plt.ylabel('Density')
plt.legend()
plt.savefig('KDE.png')

# %%
import pickle
kde_data = {
    'dataset': kde.dataset,
    'bandwidth': kde.factor
}

with open('distributions/trip_distance.pkl', 'wb') as file:
    pickle.dump(kde_data, file)
